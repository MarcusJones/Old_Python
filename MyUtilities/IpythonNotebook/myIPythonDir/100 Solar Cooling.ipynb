# %%
import pandas as pd
print pd.__version__
import scipy.io
import csv
# Out:
# 0.12.0

# %% [markdown]
# Load Exergy frames

# %%
import sys
sys.path.append('C:\EclipseWorkspace\ExergyFrames\src')
from exergyframes import exergy_frame as xrg

# %% [markdown]
# Load utils

# %%
import sys
sys.path.append('C:\EclipseWorkspace\MyUtilities\src')
import UtilityPathsAndDirs as util_dir

# %%
PROJECT_DIR = r'C:\thisProjDir'

# %%
result_file_paths = util_dir.get_files_by_name_ext(PROJECT_DIR, "result", "csv")

# %%
res_csvs = list()
for res_file_path in result_file_paths:
    
    this_csv = csv.reader(open(res_file_path), dialect='excel')
    print this_csv
    res_csvs.append(this_csv)

# %%
import re
head_frames = list()
for csv_file in res_csvs:
    count = 0
    head_frame = dict()
    for line in csv_file:
        #print(line[0], re.search('d',line[0]))
        head_frame[line[0]] = line[1:]
        if re.search('d',line[0]):
            break
        count = count + 1
        if count > 50:
            raise Exception(line)
    head_frames.append(head_frame)

# %%
#print head_frames[0]
for k,v in head_frames[0].iteritems():
    print k
    #print k,v
# Out:
# fullFilePath
# description
# labels
# variant
# number
# system
# source
# units
# pointType

# %%
unique_tups = zip(head_frames[0]['system'], head_frames[0]['pointType'],head_frames[0]['number'],head_frames[0]['labels'])
unique_keys = list()
for tup in unique_tups:
    unique_keys.append(" ".join(tup))
head_frames[0]['point key'] = unique_keys

# %%
df = pd.DataFrame(head_frames[0])

# %%
df.ix[:5]
# Out:
#                description                                       fullFilePath  \
# point key
# Bldg Zone 1 T               C:\thisProjDir\5--AUT_Graz.112400_IWEC\out\Bld...
# Bldg Zone 1 W               C:\thisProjDir\5--AUT_Graz.112400_IWEC\out\Bld...
# Bldg Zone 11 T              C:\thisProjDir\5--AUT_Graz.112400_IWEC\out\Bld...
# Bldg Zone 11 W              C:\thisProjDir\5--AUT_Graz.112400_IWEC\out\Bld...
# Bldg Zone 12 T              C:\thisProjDir\5--AUT_Graz.112400_IWEC\out\Bld...
#
#                labels number       point key pointType        source system  \
# point key
# Bldg Zone 1 T       T      1   Bldg Zone 1 T      Zone   Bldg_Zone_1   Bldg
# Bldg Zone 1 W       W      1   Bldg Zone 1 W      Zone   Bldg_Zone_1   Bldg
# Bldg Zone 11 T      T     11  Bldg Zone 11 T      Zone  Bldg_Zone_11   Bldg
# Bldg Zone 11 W      W     11  Bldg Zone 11 W      Zone  Bldg_Zone_11   Bldg
# Bldg Zone 12 T      T     12  Bldg Zone 12 T      Zone  Bldg_Zone_12   Bldg
#
# ...

# %%
df.ix['Bldg Zone 1 T']
# Out:
# description
# fullFilePath    C:\thisProjDir\5--AUT_Graz.112400_IWEC\out\Bld...
# labels                                                          T
# number                                                          1
# point key                                           Bldg Zone 1 T
# pointType                                                    Zone
# source                                                Bldg_Zone_1
# system                                                       Bldg
# units                                                         [C]
# variant                                   5--AUT_Graz.112400_IWEC
# Name: Bldg Zone 1 T, dtype: object

# %%
df.index = df.ix[:, 'point key']

# %%
res_frames = list()
for res_f_path in result_file_paths:
    res_frames.append(pd.io.parsers.read_csv(res_f_path))

# %%
#for line in this_csv:
#    print(line)

# %%
#print res_frames[0]

# %% [markdown]
# OLD

# %%
result_file_paths = util_dir.getFilesByExtRecurse(PROJECT_DIR,"mat")

# %%
for res_f_path in result_file_paths:
    #pd.io.pytables.read_hdf(res_f_path,)
    #print res_f_path
    mat = scipy.io.loadmat(res_f_path)

# %%
ignore = ['__version__', '__header__', '__globals__']

for item1 in mat:
    if item1 not in ignore:
        for item2 in mat[item1]:
            print type(item2)
            print np.shape(item2)
            for item3 in item2[0][0]:
                print np.shape(item3)
                for item4 in item3:
                    print item4
            
    
#print mat['__header__']
# Out:
# <type 'numpy.ndarray'>
# (1L,)
# (36L,)
# [u'T']
# [u'W']
# [u'T']
# [u'W']
# [u'T']
# [u'W']
# [u'T']
# [u'W']
# [u'T']
# [u'W']
# [u'T']
# [u'W']
# [u'T']
# [u'W']
# [u'T']
# [u'W']
# [u'T']
# [u'W']
# [u'T']
# [u'W']
# [u'T']
# [u'W']
# [u'T']
# [u'W']
# [u'T']
# [u'W']
# [u'T']
# [u'W']
# [u'T']
# [u'W']
# [u'T']
# [u'W']
# [u'T']
# [u'W']
# [u'T']
# [u'W']
# (36L,)
# [u'[C]']
# [u'[-]']
# [u'[C]']
# [u'[-]']
# [u'[C]']
# [u'[-]']
# [u'[C]']
# [u'[-]']
# [u'[C]']
# [u'[-]']
# [u'[C]']
# [u'[-]']
# [u'[C]']
# [u'[-]']
# [u'[C]']
# [u'[-]']
# [u'[C]']
# [u'[-]']
# [u'[C]']
# [u'[-]']
# [u'[C]']
# [u'[-]']
# [u'[C]']
# [u'[-]']
# [u'[C]']
# [u'[-]']
# [u'[C]']
# [u'[-]']
# [u'[C]']
# [u'[-]']
# [u'[C]']
# [u'[-]']
# [u'[C]']
# [u'[-]']
# [u'[C]']
# [u'[-]']
# (36L,)
# [u'Bldg_Zone_1']
# [u'Bldg_Zone_1']
# [u'Bldg_Zone_11']
# [u'Bldg_Zone_11']
# [u'Bldg_Zone_12']
# [u'Bldg_Zone_12']
# [u'Bldg_Zone_13']
# [u'Bldg_Zone_13']
# [u'Bldg_Zone_14']
# [u'Bldg_Zone_14']
# [u'Bldg_Zone_15']
# ...
