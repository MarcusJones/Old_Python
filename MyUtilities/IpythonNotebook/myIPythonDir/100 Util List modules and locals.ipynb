# %%
import sys
sys.modules.keys()
# Out:
# ['IPython.config.re',
#  'IPython.core.error',
#  'logging.atexit',
#  'IPython.external.ssh.forward',
#  'IPython.zmq.platform',
#  'Config.os',
#  'IPython.zmq.ipkernel',
#  'ctypes.os',
#  'runpy',
#  'gc',
#  'matplotlib.tempfile',
#  'Crypto.Cipher.Blowfish',
#  'IPython.external.ssh.IPython',
#  'Crypto.Cipher.AES',
#  'IPython.utils.pprint',
#  'zmq.core._poll',
#  'logging.weakref',
#  'pprint',
#  'IPython.external.ssh.warnings',
#  'Crypto.PublicKey.RSA',
#  'paramiko.proxy',
#  'IPython.zmq.IPython',
#  'Crypto.Hash.MD5',
#  'paramiko.threading',
#  'unittest.sys',
#  'numpy.core.umath',
#  'zmq',
#  'matplotlib.streamplot',
#  'Crypto.Hash.Crypto',
#  'matplotlib.matplotlib',
#  'string',
#  'IPython.config.sys',
#  'numpy.testing.os',
#  'zmq.core.poll',
#  'numpy.lib.arraysetops',
#  'encodings.utf_8',
#  'unittest.types',
#  'matplotlib.pylab',
#  'paramiko.fnmatch',
#  'matplotlib._path',
#  'IPython.zmq.datetime',
#  'paramiko.sftp_server',
#  'json.encoder',
# ...

# %%
import types
def imports():
    for name, val in globals().items():
        if isinstance(val, types.ModuleType):
            yield val.__name__

# %%
for imp in imports():
    print imp
# Out:
# matplotlib.pylab
# __builtin__
# numpy
# numpy
# matplotlib.pyplot
# matplotlib.mlab
# matplotlib
# sys
# types
# IPython.core.shadowns
# matplotlib.pyplot
