# %%
# Setup and imports
#%pylab inline
from __future__ import division

import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats as stats
import scipy as sp
import pandas as pd
print "Scipy:", sp.__version__
print "Numpy:", np.__version__
print "Matplotlib:", mpl.__version__
print "Python:", sys.version
print "Pandas:", pd.__version__
print "PyLab:", pylab.__version__
#print "ipython:", ipython.__version__
assert np.__version__ == "1.7.0" 
assert mpl.__version__ == "1.2.1rc1"
assert pd.__version__ == "0.10.1"

import statsmodels.api as sm
from IPython.core.display import HTML
import pyper as pr # Pyper 1.1.1, http://www.webarray.org/softwares/PypeR/
import re
import csv
# Out:
# Scipy: 0.11.0
# Numpy: 1.7.0
# Matplotlib: 1.2.1rc1
# Python: 2.7.2 (default, Jun 24 2011, 12:22:14) [MSC v.1500 64 bit (AMD64)]
# Pandas: 0.10.1
# PyLab: 1.7.0

# %%
# Some settings
PLOT_WIDE = [8,5] # Width, Height -Inches
PLOT_LARGE = [8,8]
PLOT_A6 = [1/2.54*14.8, 1/2.54 * 10.5]
PLOT_A6 = [5.8, 4.10]
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 12}
matplotlib.rc('font', **font)

# %%
r = pr.R(RCMD=r"C:\Apps\R\R-2.15.2\bin\x64\R.exe") # The R instance

# %%
print r("library(ISwR)")
print r("attach(secher)")
secher= r.get("secher")
print secher
# Out:
# try({library(ISwR)})
# Warning message:
# package 'ISwR' was built under R version 2.15.3
#
# try({attach(secher)})
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 107 entries, 1 to 107
# Data columns:
# bwt    107  non-null values
# bpd    107  non-null values
# ad     107  non-null values
# no     107  non-null values
# dtypes: int64(4)

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
fig.set_size_inches(*PLOT_A6)
ax = fig.add_subplot(111, projection='3d')
#
#print secher
fig = ax.scatter(secher.bpd, secher.ad, secher.bwt)
ax.view_init(30, 120)
